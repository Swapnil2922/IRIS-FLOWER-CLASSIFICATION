# %% [markdown]
# # IRIS FLOWER CLASSIFICATION

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
data = pd.read_csv("E:\DATA SCIENCE COURCE\PYTHON\OASIS PROJECT\IRIS FLOWER CLASSIFICATION\Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Delete Columns

# %%
data = data.drop(columns =['Id'])

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data.shape
# Out:
# (150, 5)

# %%
data.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # IRIS FLOWER CLASSIFICATION: Data Visualization

# %%
data.columns= ["SepalLengthCm","SepalWidthCm","PetalLengthCm",
               "PetalWidthCm","Species"]
plt.title("IRIS FLOWER CLASSIFICATION")
sns.histplot(x="SepalLengthCm", hue="Species", data=data)
plt.show()

# %%
data['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
data['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
data['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
data['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
sns.countplot(x = 'Species',data=data)
plt.show()

# %%
colors=['red','black','blue']
Species=['Iris-setosa','Iris-versicolor Species','Iris-virginica']

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=data)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',
                hue='Species',
                data=data)
plt.show()

# %%
sns.regplot(x='SepalLengthCm', y='SepalWidthCm', data=data)
plt.show()

# %%
#facets

g = sns.FacetGrid(data, col="Species")
g.map(plt.hist, "SepalLengthCm")
plt.show()

# %%
g = sns.FacetGrid(data, row="Species")
g.map(plt.hist, "SepalLengthCm")
plt.show()

# %%
g = sns.FacetGrid(data, col="Species")
g.map(plt.scatter, "SepalLengthCm","SepalWidthCm")
plt.show()

# %%
#jointplot

sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=data)
plt.show()

sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=data,kind="reg")
plt.show()

# %%
#Pairs plot\matrix plot

sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data, hue="Species")
plt.show()

# %%
data.corr
# Out:
# <bound method DataFrame.corr of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
#Heatmap

import seaborn as sns
sns.heatmap(data.corr(),annot=True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14456\2500444782.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)

# %%
sns.heatmap(data.corr(),cmap="YlGnBu",annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14456\1714143499.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap="YlGnBu",annot=True)

# %% [markdown]
# # Summary

# %% [markdown]
# Thus, this is how the Python programming language may be used to analyse the unemployment rate. The number of unemployed people as a percentage of the labour force is known as the unemployment rate, and it is used to measure unemployment. This Python article about unemployment rate analysis was hopefully enjoyable for you. Please feel free to post any insightful queries in the section below the comments.
